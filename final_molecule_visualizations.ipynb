# %%
import pandas as pd
import networkx as nx
import ast
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
import numpy as np

# %%
from ogb.graphproppred import GraphPropPredDataset

dataset = GraphPropPredDataset(name = "ogbg-molpcba")

split_idx = dataset.get_idx_split()
train_idx, valid_idx, test_idx = split_idx["train"], split_idx["valid"], split_idx["test"]

graph, label = dataset[349519]
# Out:
# Downloading http://snap.stanford.edu/ogb/data/graphproppred/csv_mol_download/pcba.zip
# Downloaded 0.04 GB: 100%|██████████| 39/39 [00:19<00:00,  2.02it/s]
# Extracting dataset\pcba.zip
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████| 437929/437929 [00:04<00:00, 99912.61it/s]
# Saving...

# %%
# Get the number of nodes for each graph in the dataset
num_nodes_list = [(i, dataset[i][0]['num_nodes']) for i in range(len(dataset))]

# Sort the list by the number of nodes in descending order
num_nodes_list.sort(key=lambda x: x[1], reverse=True)

# Get the top 5 graphs with the most nodes
top_5_graphs = num_nodes_list[:120]

# Print the results
for idx, num_nodes in top_5_graphs:
    print(f"Graph index: {idx}, Number of nodes: {num_nodes}")
# Out:
# Graph index: 349519, Number of nodes: 332
# Graph index: 17365, Number of nodes: 331
# Graph index: 302589, Number of nodes: 322
# Graph index: 346969, Number of nodes: 313
# Graph index: 182987, Number of nodes: 311
# Graph index: 390365, Number of nodes: 309
# Graph index: 349517, Number of nodes: 304
# Graph index: 104782, Number of nodes: 303
# Graph index: 17363, Number of nodes: 302
# Graph index: 272369, Number of nodes: 302
# Graph index: 274645, Number of nodes: 302
# Graph index: 363468, Number of nodes: 301
# Graph index: 296001, Number of nodes: 300
# Graph index: 349523, Number of nodes: 300
# Graph index: 272370, Number of nodes: 294
# Graph index: 37503, Number of nodes: 290
# Graph index: 46677, Number of nodes: 287
# Graph index: 321265, Number of nodes: 285
# Graph index: 17368, Number of nodes: 284
# Graph index: 200269, Number of nodes: 284
# Graph index: 351095, Number of nodes: 283
# Graph index: 403909, Number of nodes: 281
# Graph index: 389796, Number of nodes: 277
# Graph index: 361070, Number of nodes: 276
# Graph index: 381301, Number of nodes: 274
# Graph index: 17366, Number of nodes: 273
# Graph index: 389658, Number of nodes: 272
# Graph index: 230226, Number of nodes: 269
# Graph index: 104795, Number of nodes: 266
# Graph index: 227202, Number of nodes: 259
# Graph index: 351100, Number of nodes: 257
# Graph index: 90310, Number of nodes: 246
# Graph index: 226022, Number of nodes: 244
# Graph index: 331204, Number of nodes: 239
# Graph index: 130371, Number of nodes: 234
# Graph index: 345053, Number of nodes: 234
# Graph index: 257652, Number of nodes: 225
# Graph index: 247515, Number of nodes: 221
# Graph index: 104794, Number of nodes: 220
# Graph index: 17367, Number of nodes: 219
# Graph index: 161916, Number of nodes: 214
# Graph index: 381312, Number of nodes: 212
# Graph index: 431054, Number of nodes: 212
# Graph index: 177513, Number of nodes: 210
# Graph index: 388892, Number of nodes: 208
# Graph index: 37498, Number of nodes: 206
# Graph index: 112010, Number of nodes: 203
# Graph index: 277706, Number of nodes: 203
# Graph index: 76235, Number of nodes: 201
# Graph index: 424807, Number of nodes: 201
# Graph index: 322873, Number of nodes: 192
# Graph index: 166700, Number of nodes: 188
# Graph index: 112512, Number of nodes: 183
# Graph index: 323670, Number of nodes: 180
# Graph index: 381236, Number of nodes: 177
# Graph index: 272374, Number of nodes: 175
# Graph index: 288991, Number of nodes: 173
# Graph index: 227232, Number of nodes: 169
# Graph index: 322875, Number of nodes: 168
# Graph index: 101153, Number of nodes: 165
# Graph index: 357579, Number of nodes: 162
# Graph index: 357591, Number of nodes: 162
# Graph index: 217350, Number of nodes: 161
# Graph index: 202712, Number of nodes: 160
# Graph index: 104787, Number of nodes: 153
# Graph index: 178704, Number of nodes: 153
# Graph index: 369886, Number of nodes: 153
# Graph index: 288992, Number of nodes: 152
# Graph index: 105446, Number of nodes: 151
# Graph index: 166334, Number of nodes: 142
# Graph index: 293962, Number of nodes: 140
# Graph index: 349522, Number of nodes: 139
# Graph index: 101185, Number of nodes: 135
# Graph index: 357601, Number of nodes: 135
# Graph index: 256277, Number of nodes: 134
# Graph index: 101117, Number of nodes: 133
# Graph index: 11549, Number of nodes: 132
# Graph index: 53350, Number of nodes: 130
# Graph index: 252879, Number of nodes: 129
# Graph index: 272790, Number of nodes: 128
# Graph index: 333835, Number of nodes: 128
# Graph index: 166463, Number of nodes: 127
# Graph index: 272373, Number of nodes: 127
# Graph index: 290586, Number of nodes: 127
# Graph index: 376996, Number of nodes: 127
# Graph index: 133673, Number of nodes: 126
# Graph index: 176880, Number of nodes: 124
# Graph index: 196808, Number of nodes: 124
# Graph index: 115839, Number of nodes: 123
# Graph index: 26008, Number of nodes: 122
# Graph index: 429390, Number of nodes: 122
# Graph index: 148667, Number of nodes: 121
# Graph index: 178705, Number of nodes: 121
# Graph index: 36982, Number of nodes: 119
# Graph index: 90427, Number of nodes: 119
# Graph index: 107900, Number of nodes: 119
# Graph index: 390364, Number of nodes: 119
# Graph index: 405143, Number of nodes: 119
# Graph index: 350000, Number of nodes: 118
# Graph index: 306430, Number of nodes: 117
# Graph index: 306795, Number of nodes: 117
# Graph index: 256844, Number of nodes: 116
# Graph index: 197628, Number of nodes: 115
# Graph index: 206305, Number of nodes: 115
# Graph index: 346240, Number of nodes: 115
# Graph index: 347350, Number of nodes: 115
# Graph index: 383879, Number of nodes: 115
# Graph index: 8623, Number of nodes: 114
# Graph index: 143495, Number of nodes: 114
# Graph index: 363573, Number of nodes: 114
# Graph index: 334250, Number of nodes: 113
# Graph index: 94869, Number of nodes: 112
# Graph index: 436523, Number of nodes: 112
# Graph index: 171378, Number of nodes: 111
# Graph index: 135255, Number of nodes: 110
# Graph index: 230245, Number of nodes: 110
# Graph index: 256831, Number of nodes: 110
# Graph index: 259182, Number of nodes: 110
# Graph index: 124449, Number of nodes: 109
# Graph index: 135257, Number of nodes: 109

# %%
# so use 182987, 135257 , 200289, 104795
# (tested by plotting them before hand)
graph_list = [182987, 135257, 200289, 104795]

# %%
graph, label = dataset[135257] 
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

edge_index = graph['edge_index']
num_nodes = graph['num_nodes']

G = nx.Graph()

G.add_nodes_from(range(num_nodes))

edges = list(zip(edge_index[0], edge_index[1]))
G.add_edges_from(edges)

plt.figure(figsize=(10, 10))
nx.draw(G, with_labels=True, node_color='skyblue', edge_color='gray', node_size=500, font_size=10)
plt.title("Network Graph")
plt.show()

# %%
# so use 182987, 135257 , 200289, 104795
graph, label = dataset[182987]

# %%
edge_index = graph['edge_index']
num_nodes = graph['num_nodes']
G = nx.Graph()

G.add_nodes_from(range(num_nodes))

edges = list(zip(edge_index[0], edge_index[1]))
G.add_edges_from(edges)

# %%
results = pd.read_csv('subgroups_graph_182987.csv')

# %%
graph_list = [182987, 135257, 200289, 104795]

#[159, 158, 160, 156, 163, 162, 161, 164, 155, 157]","[159, 158, 160, 156]"
#[272, 274, 273, 264, 263, 265, 275, 278, 261, 279, 266, 276, 277]","[272, 274, 273, 264, 263]"


prototypes = [159, 272]

reference_groups = {
    159: [159, 158, 160, 156, 163, 162, 161, 164, 155, 157],
    272: [272, 274, 273, 264, 263, 265, 275, 278, 261, 279, 266, 276, 277]
}
subgroups = {
    159: [159, 158, 160, 156],
    272: [272, 274, 273, 264, 263]
}

# %%
def get_node_status(node, prototype):
    index_prototype = results[results['Unnamed: 0'] == prototype].index[0]
    ranks_list = ast.literal_eval(results['ranks'][index_prototype])
    for rank_node, status in ranks_list:
        if rank_node == node:
            return status

prototype_nodes_true = []
prototype_nodes_false = []
subgroup_nodes_true = []
subgroup_nodes_false = []
reference_group_nodes_true = []
reference_group_nodes_false = []
therest_nodes = set(G.nodes())

for prototype in prototypes:
    prototype_nodes = [node for node in G.nodes() if node == prototype]
    prototype_nodes_true.extend([node for node in prototype_nodes if get_node_status(node, prototype)])
    prototype_nodes_false.extend([node for node in prototype_nodes if not get_node_status(node, prototype)])

    subgroup_nodes = [node for node in subgroups[prototype] if node != prototype]
    subgroup_nodes_true.extend([node for node in subgroup_nodes if get_node_status(node, prototype)])
    subgroup_nodes_false.extend([node for node in subgroup_nodes if not get_node_status(node, prototype)])

    reference_group_nodes = [node for node in reference_groups[prototype] if node not in subgroups[prototype] and node != prototype]
    reference_group_nodes_true.extend([node for node in reference_group_nodes if get_node_status(node, prototype)])
    reference_group_nodes_false.extend([node for node in reference_group_nodes if not get_node_status(node, prototype)])

    therest_nodes -= set(reference_groups[prototype])
    therest_nodes -= set([prototype])

therest_group_nodes_true = [node for node in therest_nodes if get_node_status(node, prototype)]
therest_group_nodes_false = [node for node in therest_nodes if not get_node_status(node, prototype)]

plt.figure(figsize=(10, 10))
position = nx.spring_layout(G)

nx.draw_networkx_edges(G, pos=position, edge_color='gray')

nx.draw_networkx_nodes(G, pos=position, nodelist=prototype_nodes_true, node_color='#000000', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=prototype_nodes_false, node_color='#000000', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=subgroup_nodes_true, node_color='#14a3c7', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=subgroup_nodes_false, node_color='#14a3c7', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=reference_group_nodes_true, node_color='#A020F0', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=reference_group_nodes_false, node_color='#A020F0', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=therest_group_nodes_true, node_color='lightgray', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=therest_group_nodes_false, node_color='lightgray', node_shape='s', node_size=200)

circle_marker = Line2D([0], [0], marker='o', color='black', label='Target variable True', markersize=10, linestyle='None', markerfacecolor='black', alpha=0.5)
square_marker = Line2D([0], [0], marker='s', color='black', label='Target variable False', markersize=10, linestyle='None', markerfacecolor='black', alpha=0.5)

prototype_marker = Line2D([0], [0], marker='s', color='#000000', label='Prototype', markersize=10, linestyle='None', markerfacecolor='#000000', alpha=1)
subgroup_marker = Line2D([0], [0], marker='s', color='#14a3c7', label='Subgroup', markersize=10, linestyle='None', markerfacecolor='#14a3c7', alpha=1)
reference_marker = Line2D([0], [0], marker='s', color='#A020F0', label='Reference Group', markersize=10, linestyle='None', markerfacecolor='#A020F0', alpha=1)
therest_marker = Line2D([0], [0], marker='s', color='lightgray', label='Not considered', markersize=10, linestyle='None', markerfacecolor='lightgray', alpha=1)

plt.legend(handles=[circle_marker, square_marker, subgroup_marker, reference_marker, prototype_marker, therest_marker], loc='upper right', fontsize='x-large')

plt.show()

# %%
# so use 182987, 135257 , 200289, 104795



graph, label = dataset[135257] 

# [11, 10, 13, 12, 14]","[11, 10, 13]"
#"[58, 59, 57, 60, 61]","[58, 59, 57]"

edge_index = graph['edge_index']
num_nodes = graph['num_nodes']
G = nx.Graph()

G.add_nodes_from(range(num_nodes))

edges = list(zip(edge_index[0], edge_index[1]))
G.add_edges_from(edges)

results = pd.read_csv('subgroups_graph_135257.csv')


prototypes = [11, 58]

reference_groups = {
    11: [11, 10, 13, 12, 14],
    58: [58, 59, 57, 60, 61]
}
subgroups = {
    11: [11, 10, 13],
    58: [58, 59, 57]
}

def get_node_status(node, prototype):
    index_prototype = results[results['Unnamed: 0'] == prototype].index[0]
    ranks_list = ast.literal_eval(results['ranks'][index_prototype])
    for rank_node, status in ranks_list:
        if rank_node == node:
            return status

prototype_nodes_true = []
prototype_nodes_false = []
subgroup_nodes_true = []
subgroup_nodes_false = []
reference_group_nodes_true = []
reference_group_nodes_false = []
therest_nodes = set(G.nodes())

for prototype in prototypes:
    prototype_nodes = [node for node in G.nodes() if node == prototype]
    prototype_nodes_true.extend([node for node in prototype_nodes if get_node_status(node, prototype)])
    prototype_nodes_false.extend([node for node in prototype_nodes if not get_node_status(node, prototype)])

    subgroup_nodes = [node for node in subgroups[prototype] if node != prototype]
    subgroup_nodes_true.extend([node for node in subgroup_nodes if get_node_status(node, prototype)])
    subgroup_nodes_false.extend([node for node in subgroup_nodes if not get_node_status(node, prototype)])

    reference_group_nodes = [node for node in reference_groups[prototype] if node not in subgroups[prototype] and node != prototype]
    reference_group_nodes_true.extend([node for node in reference_group_nodes if get_node_status(node, prototype)])
    reference_group_nodes_false.extend([node for node in reference_group_nodes if not get_node_status(node, prototype)])

    therest_nodes -= set(reference_groups[prototype])
    therest_nodes -= set([prototype])

therest_group_nodes_true = [node for node in therest_nodes if get_node_status(node, prototype)]
therest_group_nodes_false = [node for node in therest_nodes if not get_node_status(node, prototype)]

plt.figure(figsize=(10, 10))
position = nx.spring_layout(G)

nx.draw_networkx_edges(G, pos=position, edge_color='gray')

nx.draw_networkx_nodes(G, pos=position, nodelist=prototype_nodes_true, node_color='#000000', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=prototype_nodes_false, node_color='#000000', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=subgroup_nodes_true, node_color='#14a3c7', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=subgroup_nodes_false, node_color='#14a3c7', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=reference_group_nodes_true, node_color='#A020F0', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=reference_group_nodes_false, node_color='#A020F0', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=therest_group_nodes_true, node_color='lightgray', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=therest_group_nodes_false, node_color='lightgray', node_shape='s', node_size=200)

circle_marker = Line2D([0], [0], marker='o', color='black', label='Target variable True', markersize=10, linestyle='None', markerfacecolor='black', alpha=0.5)
square_marker = Line2D([0], [0], marker='s', color='black', label='Target variable False', markersize=10, linestyle='None', markerfacecolor='black', alpha=0.5)

prototype_marker = Line2D([0], [0], marker='s', color='#000000', label='Prototype', markersize=10, linestyle='None', markerfacecolor='#000000', alpha=1)
subgroup_marker = Line2D([0], [0], marker='s', color='#14a3c7', label='Subgroup', markersize=10, linestyle='None', markerfacecolor='#14a3c7', alpha=1)
reference_marker = Line2D([0], [0], marker='s', color='#A020F0', label='Reference Group', markersize=10, linestyle='None', markerfacecolor='#A020F0', alpha=1)
therest_marker = Line2D([0], [0], marker='s', color='lightgray', label='Not considered', markersize=10, linestyle='None', markerfacecolor='lightgray', alpha=1)

plt.legend(handles=[circle_marker, square_marker, subgroup_marker, reference_marker, prototype_marker, therest_marker], loc='upper right', fontsize='x-large')

plt.show()

# %%
# so use 182987, 135257 , 200289, 104795



graph, label = dataset[200289] 

# [29, 30, 28, 27, 25, 31, 34]","[29, 30, 28, 27]"
# [13, 15, 12, 14, 16, 17, 18, 11, 10, 9, 19]","[13, 15, 12]"

edge_index = graph['edge_index']
num_nodes = graph['num_nodes']
G = nx.Graph()

G.add_nodes_from(range(num_nodes))

edges = list(zip(edge_index[0], edge_index[1]))
G.add_edges_from(edges)

results = pd.read_csv('subgroups_graph_200289.csv')


prototypes = [29, 13]

reference_groups = {
    29: [29, 30, 28, 27, 25, 31, 34],
    13: [13, 15, 12, 14, 16, 17, 18, 11, 10, 9, 19]
}
subgroups = {
    29: [29, 30, 28, 27],
    13: [13, 15, 12]
}

def get_node_status(node, prototype):
    index_prototype = results[results['Unnamed: 0'] == prototype].index[0]
    ranks_list = ast.literal_eval(results['ranks'][index_prototype])
    for rank_node, status in ranks_list:
        if rank_node == node:
            return status

prototype_nodes_true = []
prototype_nodes_false = []
subgroup_nodes_true = []
subgroup_nodes_false = []
reference_group_nodes_true = []
reference_group_nodes_false = []
therest_nodes = set(G.nodes())

for prototype in prototypes:
    prototype_nodes = [node for node in G.nodes() if node == prototype]
    prototype_nodes_true.extend([node for node in prototype_nodes if get_node_status(node, prototype)])
    prototype_nodes_false.extend([node for node in prototype_nodes if not get_node_status(node, prototype)])

    subgroup_nodes = [node for node in subgroups[prototype] if node != prototype]
    subgroup_nodes_true.extend([node for node in subgroup_nodes if get_node_status(node, prototype)])
    subgroup_nodes_false.extend([node for node in subgroup_nodes if not get_node_status(node, prototype)])

    reference_group_nodes = [node for node in reference_groups[prototype] if node not in subgroups[prototype] and node != prototype]
    reference_group_nodes_true.extend([node for node in reference_group_nodes if get_node_status(node, prototype)])
    reference_group_nodes_false.extend([node for node in reference_group_nodes if not get_node_status(node, prototype)])

    therest_nodes -= set(reference_groups[prototype])
    therest_nodes -= set([prototype])

therest_group_nodes_true = [node for node in therest_nodes if get_node_status(node, prototype)]
therest_group_nodes_false = [node for node in therest_nodes if not get_node_status(node, prototype)]

plt.figure(figsize=(10, 10))
position = nx.spring_layout(G)

nx.draw_networkx_edges(G, pos=position, edge_color='gray')

nx.draw_networkx_nodes(G, pos=position, nodelist=prototype_nodes_true, node_color='#000000', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=prototype_nodes_false, node_color='#000000', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=subgroup_nodes_true, node_color='#14a3c7', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=subgroup_nodes_false, node_color='#14a3c7', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=reference_group_nodes_true, node_color='#A020F0', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=reference_group_nodes_false, node_color='#A020F0', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=therest_group_nodes_true, node_color='lightgray', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=therest_group_nodes_false, node_color='lightgray', node_shape='s', node_size=200)

circle_marker = Line2D([0], [0], marker='o', color='black', label='Target variable True', markersize=10, linestyle='None', markerfacecolor='black', alpha=0.5)
square_marker = Line2D([0], [0], marker='s', color='black', label='Target variable False', markersize=10, linestyle='None', markerfacecolor='black', alpha=0.5)

prototype_marker = Line2D([0], [0], marker='s', color='#000000', label='Prototype', markersize=10, linestyle='None', markerfacecolor='#000000', alpha=1)
subgroup_marker = Line2D([0], [0], marker='s', color='#14a3c7', label='Subgroup', markersize=10, linestyle='None', markerfacecolor='#14a3c7', alpha=1)
reference_marker = Line2D([0], [0], marker='s', color='#A020F0', label='Reference Group', markersize=10, linestyle='None', markerfacecolor='#A020F0', alpha=1)
therest_marker = Line2D([0], [0], marker='s', color='lightgray', label='Not considered', markersize=10, linestyle='None', markerfacecolor='lightgray', alpha=1)

plt.legend(handles=[circle_marker, square_marker, subgroup_marker, reference_marker, prototype_marker, therest_marker], loc='upper right', fontsize='x-large')

#nx.draw_networkx_labels(G, pos=position, labels={node: node for node in G.nodes()}, font_size=12, font_color='black')
plt.show()

# %%
# so use 182987, 135257 , 200289, 104795



graph, label = dataset[104795] 

# [199, 197, 200, 198, 201, 254, 196, 203, 192, 202, 256]","[199, 197, 200, 198, 201, 254, 196]"
# [113, 111, 114, 112, 117, 115, 106, 105, 119, 118, 116]","[113, 111, 114, 112, 117, 115, 106]"

edge_index = graph['edge_index']
num_nodes = graph['num_nodes']
G = nx.Graph()

G.add_nodes_from(range(num_nodes))

edges = list(zip(edge_index[0], edge_index[1]))
G.add_edges_from(edges)

results = pd.read_csv('subgroups_graph_104795.csv')


prototypes = [199, 113]

reference_groups = {
    199: [199, 197, 200, 198, 201, 254, 196, 203, 192, 202, 256],
    113: [113, 111, 114, 112, 117, 115, 106, 105, 119, 118, 116]
}
subgroups = {
    199: [199, 197, 200, 198, 201, 254, 196],
    113: [113, 111, 114, 112, 117, 115, 106]
}

def get_node_status(node, prototype):
    index_prototype = results[results['Unnamed: 0'] == prototype].index[0]
    ranks_list = ast.literal_eval(results['ranks'][index_prototype])
    for rank_node, status in ranks_list:
        if rank_node == node:
            return status

prototype_nodes_true = []
prototype_nodes_false = []
subgroup_nodes_true = []
subgroup_nodes_false = []
reference_group_nodes_true = []
reference_group_nodes_false = []
therest_nodes = set(G.nodes())

for prototype in prototypes:
    prototype_nodes = [node for node in G.nodes() if node == prototype]
    prototype_nodes_true.extend([node for node in prototype_nodes if get_node_status(node, prototype)])
    prototype_nodes_false.extend([node for node in prototype_nodes if not get_node_status(node, prototype)])

    subgroup_nodes = [node for node in subgroups[prototype] if node != prototype]
    subgroup_nodes_true.extend([node for node in subgroup_nodes if get_node_status(node, prototype)])
    subgroup_nodes_false.extend([node for node in subgroup_nodes if not get_node_status(node, prototype)])

    reference_group_nodes = [node for node in reference_groups[prototype] if node not in subgroups[prototype] and node != prototype]
    reference_group_nodes_true.extend([node for node in reference_group_nodes if get_node_status(node, prototype)])
    reference_group_nodes_false.extend([node for node in reference_group_nodes if not get_node_status(node, prototype)])

    therest_nodes -= set(reference_groups[prototype])
    therest_nodes -= set([prototype])

therest_group_nodes_true = [node for node in therest_nodes if get_node_status(node, prototype)]
therest_group_nodes_false = [node for node in therest_nodes if not get_node_status(node, prototype)]

plt.figure(figsize=(10, 10))
position = nx.spring_layout(G)

nx.draw_networkx_edges(G, pos=position, edge_color='gray')

nx.draw_networkx_nodes(G, pos=position, nodelist=prototype_nodes_true, node_color='#000000', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=prototype_nodes_false, node_color='#000000', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=subgroup_nodes_true, node_color='#14a3c7', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=subgroup_nodes_false, node_color='#14a3c7', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=reference_group_nodes_true, node_color='#A020F0', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=reference_group_nodes_false, node_color='#A020F0', node_shape='s', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=therest_group_nodes_true, node_color='lightgray', node_shape='o', node_size=200)
nx.draw_networkx_nodes(G, pos=position, nodelist=therest_group_nodes_false, node_color='lightgray', node_shape='s', node_size=200)

circle_marker = Line2D([0], [0], marker='o', color='black', label='Target variable True', markersize=10, linestyle='None', markerfacecolor='black', alpha=0.5)
square_marker = Line2D([0], [0], marker='s', color='black', label='Target variable False', markersize=10, linestyle='None', markerfacecolor='black', alpha=0.5)

prototype_marker = Line2D([0], [0], marker='s', color='#000000', label='Prototype', markersize=10, linestyle='None', markerfacecolor='#000000', alpha=1)
subgroup_marker = Line2D([0], [0], marker='s', color='#14a3c7', label='Subgroup', markersize=10, linestyle='None', markerfacecolor='#14a3c7', alpha=1)
reference_marker = Line2D([0], [0], marker='s', color='#A020F0', label='Reference Group', markersize=10, linestyle='None', markerfacecolor='#A020F0', alpha=1)
therest_marker = Line2D([0], [0], marker='s', color='lightgray', label='Not considered', markersize=10, linestyle='None', markerfacecolor='lightgray', alpha=1)

plt.legend(handles=[circle_marker, square_marker, subgroup_marker, reference_marker, prototype_marker, therest_marker], loc='upper right', fontsize='x-large')

#nx.draw_networkx_labels(G, pos=position, labels={node: node for node in G.nodes()}, font_size=12, font_color='black')
plt.show()
